# %%
import pandas as pd


df = pd.read_csv('ZPPA Registered Suppliers.csv')


print(df.head())
# Out:
#                                         Company Name  \
# 0  TRIUMPH YOUTH MULTI-PURPOSE C0-OPERATIVE SOCIE...
# 1                                   TAKUDZWA TRADING
# 2                              CKFK CONSTRUCTION LTD
# 3                                Lubrand Enterprises
# 4                        PURJOZ HARDWARE AND TRADING
#
#   Tax Identification Number                 Physical Address postalcode  \
# 0                2036935028                       CHOMA TOWN      10101
# 1                1005263197      CHILANGA GAME AND FISHERIES        NaN
# 2                1004048919  1100 SALAMA PARK TWIN PALM ROAD      10101
# 3                1013000801       Plot 72 Freedom Way, Kabwe      10101
# 4                1008420630       7/307 OFF GREAT NORTH ROAD        NaN
#
#   Town/City         phone                   status        Registration Date  \
# 0     CHOMA     978172069  authority.status.active  2022-06-06 13:25:34.645
# ...
